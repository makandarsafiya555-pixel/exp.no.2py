# %%
RollNo:24 Experiment2:Looping-Loop Control Statement

# %%
a=15;                                                                                  
if a>15:
    print("a is greater than 15")
elif a==15:
    print("a is equal to 15")
else:
    print("a is less than 15")
# Out:
# a is equal to 15

# %%
if 10<5:
    print("5 is greater than 10")
else:
    print("5 is less than 10")
# Out:
# 5 is less than 10

# %%
a=int(input("Enter value for a: "))
if a>60:
    print("a is greater than 60")
else:
    print("a is less than 60")
# Out:
# Enter value for a:  58
# a is less than 60

# %%
a=int(input("Enter value for a: "))
b=int(input("Enter value for b: "))
if a>=b:
    print("a is greater than b")
elif a==b:
    print("a is equal to b")
else:
    print("a is less than b")
# Out:
# Enter value for a:  67
# Enter value for b:  90
# a is less than b

# %%
for a in range(9):
    print(a)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for a in range(9,12):
    print(a)
# Out:
# 9
# 10
# 11

# %%
for a in range(9,40,4):
    print(a)
# Out:
# 9
# 13
# 17
# 21
# 25
# 29
# 33
# 37

# %%
for a in range(7,20,2):
    if a>9:
        print("a is greater than 9")
    else:
        print("a is less than 9")
# Out:
# a is less than 9
# a is less than 9
# a is greater than 9
# a is greater than 9
# a is greater than 9
# a is greater than 9
# a is greater than 9

# %%
b = 30
while b < 40:
    print("b= ", b)
    if b == 36:
        break
    b = b + 1
# Out:
# b=  30
# b=  31
# b=  32
# b=  33
# b=  34
# b=  35
# b=  36

# %%
b = 30
while b < 40:
    if b == 36:
        b = b + 1
        continue
    print("b= ", b)
    b = b + 1
# Out:
# b=  30
# b=  31
# b=  32
# b=  33
# b=  34
# b=  35
# b=  37
# b=  38
# b=  39

# %%
k = 40
while k <= 50:
    if k == 46:
        k = k + 2 
        continue
    print("k= ", k)
    k = k + 2
# Out:
# k=  40
# k=  42
# k=  44
# k=  48
# k=  50
